# %% [markdown]
# <div style="display: flex; background-color: RGB(255,114,0);" >
#
# # PROJET - Cat or Dog </h1>
# </div>

# %% [markdown]
# <div style="display: flex; background-color: blue;" >
#
# # 1.Contexte du projet
# </div>
#
# Dans ce projet, vous apprendrez les bases des CNN, leur structure, leurs composants et leur fonctionnement, et vous apprendrez pratiquement comment résoudre une tâche d'apprentissage en profondeur de classification d'images, former , et testez un réseau de neurones avec Tensorflow à l'aide d'images.
#
# - Mettez en place un système de veille
# - Import the Dataset and Preprocess the Data
# - Create and Train the Model
# - Test the Model and Make Predictions
#
# ### Jalon
#
# Date limite 07/08/2022
#
# ### Critères de performance
#
# À la fin de ce projet, vous aurez créé un réseau de neurones profonds avec TensorFlow sur un ensemble de données.
#
# ### Livrables
#
# Une présentation type "Powerpoint", faisant office de veille.
# Jupyter Notebooks : classification
#
# ### Ressources
# - train set : https://drive.google.com/drive/folders/1LLBvdZH07dtugxxHDvqArGp9lR7pQZgP?usp=sharing
# - validation set : https://drive.google.com/drive/folders/1IoUkz-y_42xv_GzmHTMfb0hdVk-rrWWK?usp=sharing
# - cats-train : https://drive.google.com/drive/folders/1xODwWAdtDLPVftnG8wM41sTQxgAbg81G?usp=sharing
# - Your First Deep Learning with Keras Step-By-Step : https://machinelearningmastery.com/tutorial-first-neural-network-python-keras/
# - Mettez en place un système de veille : https://openclassrooms.com/fr/courses/4805776-mettez-en-place-un-systeme-de-veille-informationnelle

# %% [markdown]
# <div style="display: flex; background-color: blue;" >
#
# # 2.Mes ressources
# </div>

# %% [markdown]
# - https://github.com/tensorflow/datasets/blob/master/tensorflow_datasets/image_classification/cats_vs_dogs.py
# - https://www.tensorflow.org/datasets/catalog/cats_vs_dogs
# - https://www.kaggle.com/c/dogs-vs-cats/data
# - https://data-flair.training/blogs/cats-dogs-classification-deep-learning-project-beginners/
# - https://www.kaggle.com/competitions/dogs-vs-cats/overview
#
# - https://keras.io/examples/vision/image_classification_from_scratch/

# %%
import numpy as np
import pandas as pd
import random
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from os import getcwd, listdir
from os.path import join
from skimage import io
from cat_or_dog_aurelie import *

# %% [markdown]
# <div style="display: flex; background-color: blue;" >
#
# # 2.Chargement des données
# </div>

# %%
# ---------------------------------------------------------------------------------------------
#                               MAIN
# ---------------------------------------------------------------------------------------------
verbose = False

# Récupère le répertoire du programme
file_path = getcwd() + "\\"

print(f"Current execution path : {file_path}")
# Out:
# Current execution path : c:\Users\User\WORK\workspace-ia\PROJETS\projet_cat_or_dog\

# %%
source_data_path = join(file_path,"dataset")
training_data_path = join(source_data_path, "training_set")
validation_data_path = join(source_data_path, "validation_set")
print("Source path :", source_data_path)
print("Training path :", training_data_path)
print("validation path :", validation_data_path)
# Out:
# Source path : c:\Users\User\WORK\workspace-ia\PROJETS\projet_cat_or_dog\dataset
# Training path : c:\Users\User\WORK\workspace-ia\PROJETS\projet_cat_or_dog\dataset\training_set
# validation path : c:\Users\User\WORK\workspace-ia\PROJETS\projet_cat_or_dog\dataset\validation_set

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### Liste des images à récupérer
# </div>

# %%
filenames = get_dir_files(dir_path=training_data_path, verbose=0)
print(f"{len(filenames)} files detected.")
print(f"{filenames[0]} to {filenames[-1]}")
# Out:
# 2148 files detected.
# cat.1.jpg to dog.998.jpg

# %%
demo_img = join(training_data_path,filenames[0])
demo_img
# Out:
# 'c:\\Users\\User\\WORK\\workspace-ia\\PROJETS\\projet_cat_or_dog\\dataset\\training_set\\cat.1.jpg'

# %%
img_cloudy, resized_img_cloudy, hog_image_cloudy = show_hog(img_path=demo_img)

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### Chargemement des images via keras
# </div>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
image_size = (180, 180)
batch_size = 32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    training_data_path,
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    validation_data_path,
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 2148 files belonging to 2 classes.
# Using 1719 files for training.
# Found 2000 files belonging to 2 classes.
# Using 400 files for validation.

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### Visualisation
# </div>

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %% [markdown]
# <div style="display: flex; background-color: blue;" >
#
# # 3.Pre-processing
# </div>

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### data augmentation : oui ou non ?
# </div>
#
# A priori lorsqu'on dispose de peu de données il est recommandé d'appliquer ce traitement pour avoir différents points de vue d'une même image et donc avoir plus de données.

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
    ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### Standardizing the data
# </div>
#
# - size (180x180)
# - RGB channel values are in the [0, 255] range. This is not ideal for a neural network; in general you should seek to make your input values small. Here, we will standardize values to be in the [0, 1] by using a Rescaling layer at the start of our model

# %% [markdown]
# <div style="display: flex; background-color: indigo;" >
#
# #### Option 1: Make it part of the model
# </div>
#
# With this option, your data augmentation will happen on device, synchronously with the rest of the model execution, meaning that it will benefit from GPU acceleration.
#
# Note that data augmentation is inactive at test time, so the input samples will only be augmented during fit(), not when calling evaluate() or predict().
#
# If you're training on GPU, this is the better option.

# %%
# inputs = keras.Input(shape=input_shape)
# inputs = keras.Input(shape=train_ds.shape)
# x = data_augmentation(inputs)
# x = layers.Rescaling(1./255)(x)

# Rest of the model

# %% [markdown]
# <div style="display: flex; background-color: indigo;" >
#
# #### Option 2: apply it to the dataset, so as to obtain a dataset that yields batches of augmented images, like this
# </div>
#
# With this option, your data augmentation will happen on CPU, asynchronously, and will be buffered before going into the model.
#
# If you're training on CPU, this is the better option, since it makes data augmentation asynchronous and non-blocking.
#
# In our case, we'll go with the second option

# %%
augmented_train_ds = train_ds.map(
  lambda x, y: (data_augmentation(x, training=True), y))

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### Configure the dataset for performance
# </div>

# %%
train_ds = train_ds.prefetch(buffer_size=32)
val_ds = val_ds.prefetch(buffer_size=32)

# %% [markdown]
# <div style="display: flex; background-color: blue;" >
#
# # 4.Build a model
# </div>

# %%
model = make_model(input_shape=image_size + (3,), num_classes=2, data_augmentation=False)
keras.utils.plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### Train the model
# </div>

# %%
just to fail

# %%
epochs = 48
# Epoch 48/50
# 54/54 [==============================] - 181s 3s/step - loss: 0.1143 - accuracy: 0.9604 - val_loss: 0.6586 - val_accuracy: 0.8275
# Epoch 49/50
# 54/54 [==============================] - 188s 3s/step - loss: 0.1447 - accuracy: 0.9401 - val_loss: 0.9874 - val_accuracy: 0.7425
# Epoch 50/50
# in 142 minutes

callbacks = [
    keras.callbacks.ModelCheckpoint("model_check_point/color/save_at_{epoch}.h5"),
]
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
history_color = model.fit(train_ds, epochs=epochs, callbacks=callbacks, validation_data=val_ds)
# Out:
# Epoch 1/50
# 54/54 [==============================] - 158s 3s/step - loss: 0.6237 - accuracy: 0.6632 - val_loss: 0.7015 - val_accuracy: 0.5000
# Epoch 2/50
# 54/54 [==============================] - 155s 3s/step - loss: 0.5699 - accuracy: 0.7126 - val_loss: 0.8604 - val_accuracy: 0.5025
# Epoch 3/50
# 54/54 [==============================] - 152s 3s/step - loss: 0.5495 - accuracy: 0.7155 - val_loss: 0.8019 - val_accuracy: 0.5025
# Epoch 4/50
# 54/54 [==============================] - 171s 3s/step - loss: 0.5536 - accuracy: 0.7353 - val_loss: 0.7554 - val_accuracy: 0.5525
# Epoch 5/50
# 54/54 [==============================] - 183s 3s/step - loss: 0.5074 - accuracy: 0.7603 - val_loss: 0.7683 - val_accuracy: 0.5950
# Epoch 6/50
# 54/54 [==============================] - 180s 3s/step - loss: 0.4824 - accuracy: 0.7801 - val_loss: 0.5580 - val_accuracy: 0.7550
# Epoch 7/50
# 54/54 [==============================] - 178s 3s/step - loss: 0.4628 - accuracy: 0.7818 - val_loss: 0.5502 - val_accuracy: 0.7725
# Epoch 8/50
# 54/54 [==============================] - 154s 3s/step - loss: 0.4573 - accuracy: 0.7865 - val_loss: 0.7033 - val_accuracy: 0.6775
# Epoch 9/50
# 54/54 [==============================] - 156s 3s/step - loss: 0.4831 - accuracy: 0.7627 - val_loss: 0.8213 - val_accuracy: 0.6725
# Epoch 10/50
# 54/54 [==============================] - 157s 3s/step - loss: 0.4341 - accuracy: 0.7952 - val_loss: 0.8182 - val_accuracy: 0.6925
# Epoch 11/50
# 54/54 [==============================] - 197s 4s/step - loss: 0.4188 - accuracy: 0.8045 - val_loss: 0.6593 - val_accuracy: 0.7200
# Epoch 12/50
# 54/54 [==============================] - 196s 4s/step - loss: 0.4060 - accuracy: 0.8214 - val_loss: 0.5899 - val_accuracy: 0.7075
# Epoch 13/50
# 54/54 [==============================] - 176s 3s/step - loss: 0.3954 - accuracy: 0.8284 - val_loss: 0.7057 - val_accuracy: 0.7450
# Epoch 14/50
# 54/54 [==============================] - 172s 3s/step - loss: 0.3593 - accuracy: 0.8406 - val_loss: 0.5255 - val_accuracy: 0.7925
# Epoch 15/50
# 54/54 [==============================] - 193s 4s/step - loss: 0.3691 - accuracy: 0.8330 - val_loss: 1.3930 - val_accuracy: 0.5800
# Epoch 16/50
# 54/54 [==============================] - 210s 4s/step - loss: 0.3448 - accuracy: 0.8447 - val_loss: 0.5122 - val_accuracy: 0.7525
# Epoch 17/50
# 54/54 [==============================] - 190s 3s/step - loss: 0.2969 - accuracy: 0.8773 - val_loss: 0.9400 - val_accuracy: 0.6775
# Epoch 18/50
# 54/54 [==============================] - 176s 3s/step - loss: 0.3037 - accuracy: 0.8674 - val_loss: 0.5377 - val_accuracy: 0.7800
# Epoch 19/50
# 54/54 [==============================] - 170s 3s/step - loss: 0.3315 - accuracy: 0.8493 - val_loss: 0.5310 - val_accuracy: 0.7825
# Epoch 20/50
# 54/54 [==============================] - 164s 3s/step - loss: 0.2935 - accuracy: 0.8726 - val_loss: 0.5682 - val_accuracy: 0.7900
# Epoch 21/50
# 54/54 [==============================] - 175s 3s/step - loss: 0.2986 - accuracy: 0.8709 - val_loss: 1.1697 - val_accuracy: 0.6875
# Epoch 22/50
# 54/54 [==============================] - 174s 3s/step - loss: 0.2577 - accuracy: 0.8837 - val_loss: 0.5669 - val_accuracy: 0.7800
# Epoch 23/50
# 54/54 [==============================] - 176s 3s/step - loss: 0.2389 - accuracy: 0.9040 - val_loss: 0.6084 - val_accuracy: 0.7550
# Epoch 24/50
# 54/54 [==============================] - 176s 3s/step - loss: 0.2661 - accuracy: 0.8831 - val_loss: 0.5083 - val_accuracy: 0.8025
# Epoch 25/50
# 54/54 [==============================] - 164s 3s/step - loss: 0.2495 - accuracy: 0.8941 - val_loss: 0.4521 - val_accuracy: 0.8125
# Epoch 26/50
# 54/54 [==============================] - 163s 3s/step - loss: 0.2405 - accuracy: 0.9069 - val_loss: 1.2885 - val_accuracy: 0.6600
# Epoch 27/50
# 54/54 [==============================] - 173s 3s/step - loss: 0.2361 - accuracy: 0.8965 - val_loss: 0.6175 - val_accuracy: 0.7575
# Epoch 28/50
# 54/54 [==============================] - 170s 3s/step - loss: 0.2315 - accuracy: 0.9058 - val_loss: 0.6869 - val_accuracy: 0.7600
# Epoch 29/50
# 54/54 [==============================] - 160s 3s/step - loss: 0.2180 - accuracy: 0.9069 - val_loss: 0.4710 - val_accuracy: 0.8350
# Epoch 30/50
# 54/54 [==============================] - 161s 3s/step - loss: 0.1878 - accuracy: 0.9343 - val_loss: 0.6250 - val_accuracy: 0.7525
# Epoch 31/50
# 54/54 [==============================] - 161s 3s/step - loss: 0.1933 - accuracy: 0.9244 - val_loss: 0.4563 - val_accuracy: 0.8100
# Epoch 32/50
# 54/54 [==============================] - 160s 3s/step - loss: 0.1757 - accuracy: 0.9325 - val_loss: 2.9640 - val_accuracy: 0.5625
# Epoch 33/50
# 54/54 [==============================] - 167s 3s/step - loss: 0.1980 - accuracy: 0.9209 - val_loss: 0.6048 - val_accuracy: 0.7750
# Epoch 34/50
# 54/54 [==============================] - 170s 3s/step - loss: 0.1938 - accuracy: 0.9197 - val_loss: 0.4818 - val_accuracy: 0.8175
# Epoch 35/50
# 54/54 [==============================] - 191s 4s/step - loss: 0.1894 - accuracy: 0.9209 - val_loss: 0.8028 - val_accuracy: 0.7950
# Epoch 36/50
# 54/54 [==============================] - 181s 3s/step - loss: 0.1978 - accuracy: 0.9127 - val_loss: 0.5949 - val_accuracy: 0.7900
# Epoch 37/50
# 54/54 [==============================] - 170s 3s/step - loss: 0.1610 - accuracy: 0.9401 - val_loss: 0.4692 - val_accuracy: 0.8075
# Epoch 38/50
# 54/54 [==============================] - 169s 3s/step - loss: 0.1583 - accuracy: 0.9378 - val_loss: 0.5308 - val_accuracy: 0.8375
# Epoch 39/50
# 54/54 [==============================] - 180s 3s/step - loss: 0.1383 - accuracy: 0.9471 - val_loss: 0.4619 - val_accuracy: 0.8425
# Epoch 40/50
# 54/54 [==============================] - 181s 3s/step - loss: 0.1278 - accuracy: 0.9535 - val_loss: 0.5907 - val_accuracy: 0.8125
# Epoch 41/50
# 54/54 [==============================] - 168s 3s/step - loss: 0.1306 - accuracy: 0.9540 - val_loss: 0.5415 - val_accuracy: 0.8325
# Epoch 42/50
# 54/54 [==============================] - 198s 4s/step - loss: 0.1266 - accuracy: 0.9506 - val_loss: 1.0801 - val_accuracy: 0.7525
# Epoch 43/50
# 54/54 [==============================] - 182s 3s/step - loss: 0.1222 - accuracy: 0.9511 - val_loss: 0.5084 - val_accuracy: 0.8600
# Epoch 44/50
# 54/54 [==============================] - 171s 3s/step - loss: 0.1336 - accuracy: 0.9453 - val_loss: 0.7414 - val_accuracy: 0.7650
# Epoch 45/50
# 54/54 [==============================] - 172s 3s/step - loss: 0.1344 - accuracy: 0.9459 - val_loss: 0.5483 - val_accuracy: 0.8200
# Epoch 46/50
# 54/54 [==============================] - 171s 3s/step - loss: 0.1427 - accuracy: 0.9436 - val_loss: 0.6013 - val_accuracy: 0.8125
# Epoch 47/50
# 54/54 [==============================] - 179s 3s/step - loss: 0.1121 - accuracy: 0.9581 - val_loss: 0.4771 - val_accuracy: 0.8450
# Epoch 48/50
# 54/54 [==============================] - 181s 3s/step - loss: 0.1143 - accuracy: 0.9604 - val_loss: 0.6586 - val_accuracy: 0.8275
# Epoch 49/50
# 54/54 [==============================] - 188s 3s/step - loss: 0.1447 - accuracy: 0.9401 - val_loss: 0.9874 - val_accuracy: 0.7425
# Epoch 50/50
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# c:\Users\User\WORK\workspace-ia\PROJETS\projet_cat_or_dog\cat_or_dog_aurelie.ipynb Cell 33' in <cell line: 11>()
#       <a href='vscode-notebook-cell:/c%3A/Users/User/WORK/workspace-ia/PROJETS/projet_cat_or_dog/cat_or_dog_aurelie.ipynb#ch0000071?line=2'>3</a> callbacks = [
#       <a href='vscode-notebook-cell:/c%3A/Users/User/WORK/workspace-ia/PROJETS/projet_cat_or_dog/cat_or_dog_aurelie.ipynb#ch0000071?line=3'>4</a>     keras.callbacks.ModelCheckpoint("save_at_{epoch}.h5"),
#       <a href='vscode-notebook-cell:/c%3A/Users/User/WORK/workspace-ia/PROJETS/projet_cat_or_dog/cat_or_dog_aurelie.ipynb#ch0000071?line=4'>5</a> ]
#       <a href='vscode-notebook-cell:/c%3A/Users/User/WORK/workspace-ia/PROJETS/projet_cat_or_dog/cat_or_dog_aurelie.ipynb#ch0000071?line=5'>6</a> model.compile(
#       <a href='vscode-notebook-cell:/c%3A/Users/User/WORK/workspace-ia/PROJETS/projet_cat_or_dog/cat_or_dog_aurelie.ipynb#ch0000071?line=6'>7</a>     optimizer=keras.optimizers.Adam(1e-3),
#       <a href='vscode-notebook-cell:/c%3A/Users/User/WORK/workspace-ia/PROJETS/projet_cat_or_dog/cat_or_dog_aurelie.ipynb#ch0000071?line=7'>8</a>     loss="binary_crossentropy",
#       <a href='vscode-notebook-cell:/c%3A/Users/User/WORK/workspace-ia/PROJETS/projet_cat_or_dog/cat_or_dog_aurelie.ipynb#ch0000071?line=8'>9</a>     metrics=["accuracy"],
#      <a href='vscode-notebook-cell:/c%3A/Users/User/WORK/workspace-ia/PROJETS/projet_cat_or_dog/cat_or_dog_aurelie.ipynb#ch0000071?line=9'>10</a> )
# ---> <a href='vscode-notebook-cell:/c%3A/Users/User/WORK/workspace-ia/PROJETS/projet_cat_or_dog/cat_or_dog_aurelie.ipynb#ch0000071?line=10'>11</a> model.fit(
#      <a href='vscode-notebook-cell:/c%3A/Users/User/WORK/workspace-ia/PROJETS/projet_cat_or_dog/cat_or_dog_aurelie.ipynb#ch0000071?line=11'>12</a>     train_ds, epochs=epochs, callbacks=callbacks, validation_data=val_ds,
#      <a href='vscode-notebook-cell:/c%3A/Users/User/WORK/workspace-ia/PROJETS/projet_cat_or_dog/cat_or_dog_aurelie.ipynb#ch0000071?line=12'>13</a> )
#
# File c:\Program Files\Python_venv\tensor_flow\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///c%3A/Program%20Files/Python_venv/tensor_flow/lib/site-packages/keras/utils/traceback_utils.py?line=64'>65</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///c%3A/Program%20Files/Python_venv/tensor_flow/lib/site-packages/keras/utils/traceback_utils.py?line=65'>66</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> <a href='file:///c%3A/Program%20Files/Python_venv/tensor_flow/lib/site-packages/keras/utils/traceback_utils.py?line=66'>67</a>   raise e.with_traceback(filtered_tb) from None
#      <a href='file:///c%3A/Program%20Files/Python_venv/tensor_flow/lib/site-packages/keras/utils/traceback_utils.py?line=67'>68</a> finally:
#      <a href='file:///c%3A/Program%20Files/Python_venv/tensor_flow/lib/site-packages/keras/utils/traceback_utils.py?line=68'>69</a>   del filtered_tb
#
# File c:\Program Files\Python_venv\tensor_flow\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      <a href='file:///c%3A/Program%20Files/Python_venv/tensor_flow/lib/site-packages/tensorflow/python/eager/execute.py?line=51'>52</a> try:
#      <a href='file:///c%3A/Program%20Files/Python_venv/tensor_flow/lib/site-packages/tensorflow/python/eager/execute.py?line=52'>53</a>   ctx.ensure_initialized()
# ---> <a href='file:///c%3A/Program%20Files/Python_venv/tensor_flow/lib/site-packages/tensorflow/python/eager/execute.py?line=53'>54</a>   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      <a href='file:///c%3A/Program%20Files/Python_venv/tensor_flow/lib/site-packages/tensorflow/python/eager/execute.py?line=54'>55</a>                                       inputs, attrs, num_outputs)
#      <a href='file:///c%3A/Program%20Files/Python_venv/tensor_flow/lib/site-packages/tensorflow/python/eager/execute.py?line=55'>56</a> except core._NotOkStatusException as e:
#      <a href='file:///c%3A/Program%20Files/Python_venv/tensor_flow/lib/site-packages/tensorflow/python/eager/execute.py?line=56'>57</a>   if name is not None:
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x92 in position 204: invalid start byte

# %%
just to fail

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### Run inference on new data
# </div>

# %%
aurelie_test, aurelie_y = get_aurelie_test()

# %%
for i in range(0, len(aurelie_test)):
    img = keras.preprocessing.image.load_img(aurelie_test[i], target_size=image_size)
    img_array = keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create batch axis

    predictions = model.predict(img_array)
    score = predictions[0]
    print(f"- {100 * (1 - score)} % cat / {100 * score} % dog, expected : {labels[aurelie_y[i]]}")
    print(predictions)

# %% [markdown]
# <div style="display: flex; background-color: blue;" >
#
# # ANNEXES
# </div>

# %%
just to fail
# Out:
#   Input In [21]
#     just to fail
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### Création de la DF
# </div>

# %%
categories=[]
categories_names = []
file_type = []
img_height = []
img_width = []
img_dims = []

for f_name in filenames:
    category=f_name.split('.')[0]
    categories_names.append(category)
    file_type.append(f_name.split('.')[-1])
    if category=='dog':
        categories.append(1)
    else:
        categories.append(0)
    coins_image = io.imread(join(training_data_path, f_name))
    img_h = np.nan
    img_w = np.nan
    img_dim = 3

    if coins_image is not None:
        img_w = coins_image.shape[0]
        img_h = coins_image.shape[1]
        img_dim = coins_image.shape[2]
    
    img_height.append(img_h)
    img_width.append(img_w)
    img_dims.append(img_dim)
        
df=pd.DataFrame({
    'file_name':filenames,
    'file_type':file_type,
    'category_name':categories_names,
    'category':categories,
    'img_height':img_height,
    'img_width':img_width,
    'nb_dim':img_dims,
})
df
# Out:
#          file_name file_type category_name  category  img_height  img_width  \
# 0        cat.1.jpg       jpg           cat         0         300        280
# 1      cat.100.jpg       jpg           cat         0         403        499
# 2     cat.1000.jpg       jpg           cat         0         150        149
# 3     cat.1003.jpg       jpg           cat         0         259        269
# 4      cat.101.jpg       jpg           cat         0         296        200
# ...            ...       ...           ...       ...         ...        ...
# 2143   dog.987.jpg       jpg           dog         1         310        500
# 2144   dog.988.jpg       jpg           dog         1         375        499
# 2145   dog.994.jpg       jpg           dog         1         500        331
# 2146   dog.997.jpg       jpg           dog         1         249        181
# 2147   dog.998.jpg       jpg           dog         1         494        499
#
#       nb_dim
# 0          3
# 1          3
# 2          3
# 3          3
# 4          3
# ...      ...
# 2143       3
# 2144       3
# 2145       3
# 2146       3
# 2147       3
#
# [2148 rows x 7 columns]

# %%
image_Width=max(img_width)
image_Height=max(img_height)
image_Channels=max(img_dims)
print(image_Width, image_Height, image_Channels)
# Out:
# 702 1050 3

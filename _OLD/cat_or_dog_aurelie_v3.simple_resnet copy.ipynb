# %% [markdown]
# <div style="display: flex; background-color: RGB(255,114,0);" >
#
# # PROJET - Cat or Dog - V1 - Simple
# </div>

# %% [markdown]
# <div style="display: flex; background-color: blue;" >
#
# # 1.Contexte du projet
# </div>
#
# Dans ce projet, vous apprendrez les bases des CNN, leur structure, leurs composants et leur fonctionnement, et vous apprendrez pratiquement comment résoudre une tâche d'apprentissage en profondeur de classification d'images, former , et testez un réseau de neurones avec Tensorflow à l'aide d'images.
#
# - Mettez en place un système de veille
# - Import the Dataset and Preprocess the Data
# - Create and Train the Model
# - Test the Model and Make Predictions
#
# |       |                       |
# |-------|-----------------------|
# | Jalon | Date limite 07/08/2022|
# | Critères de performance | À la fin de ce projet, vous aurez créé un réseau de neurones profonds avec TensorFlow sur un ensemble de données.|
# |Livrables|Une présentation type "Powerpoint", faisant office de veille et Jupyter Notebooks : classification|
#
# ### Livrables
#
# Une présentation type "Powerpoint", faisant office de veille.
#
# Quelques questions de veille
# - C'est quoi le Deep Learning
# - Présenter la librairie Tensorflow ...
# - Qu'est-ce qu'un CNN (l'avantage, l'inconvénient, domaine d'application), est-ce qu'il y a d'algorithmes plus puissants que CNN
# - Décrire notamment comment construire un CNN et l'utilité de chaque étape
# (sinon vous pouvez représenter d'autres axes qui vous sembler intéressant à savoir avant de commencer un projet sur le Deep Learning)
#
#
# Jupyter Notebooks : classification
#
# ### Ressources
# - train set : https://drive.google.com/drive/folders/1LLBvdZH07dtugxxHDvqArGp9lR7pQZgP?usp=sharing
# - validation set : https://drive.google.com/drive/folders/1IoUkz-y_42xv_GzmHTMfb0hdVk-rrWWK?usp=sharing
# - cats-train : https://drive.google.com/drive/folders/1xODwWAdtDLPVftnG8wM41sTQxgAbg81G?usp=sharing
# - Your First Deep Learning with Keras Step-By-Step : https://machinelearningmastery.com/tutorial-first-neural-network-python-keras/
# - Mettez en place un système de veille : https://openclassrooms.com/fr/courses/4805776-mettez-en-place-un-systeme-de-veille-informationnelle

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### 1.2. Mes ressources
# </div>

# %% [markdown]
# - https://github.com/tensorflow/datasets/blob/master/tensorflow_datasets/image_classification/cats_vs_dogs.py
# - https://www.tensorflow.org/datasets/catalog/cats_vs_dogs
# - https://www.kaggle.com/c/dogs-vs-cats/data
# - https://data-flair.training/blogs/cats-dogs-classification-deep-learning-project-beginners/
# - https://www.kaggle.com/competitions/dogs-vs-cats/overview
#
# - https://keras.io/examples/vision/image_classification_from_scratch/
# - https://keras.io/api/applications/#usage-examples-for-image-classification-models

# %%
import matplotlib.pyplot as plt

from cat_or_dog_aurelie import *

import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam

from os import getcwd
from os.path import exists, join

import cv2

# %%
# ---------------------------------------------------------------------------------------------
#                               MAIN
# ---------------------------------------------------------------------------------------------
verbose = 1

# Récupère le répertoire du programme
file_path = getcwd() + "\\"

print(f"Current execution path : {file_path}")
# Out:
# Current execution path : c:\Users\User\WORK\workspace-ia\PROJETS\projet_cat_or_dog\

# %%
source_data_path = join(file_path,"dataset")
training_data_path = join(source_data_path, "training_set")
validation_data_path = join(source_data_path, "validation_set")
model_path = join(file_path, "model")
print("Source path :", source_data_path)
print("Training path :", training_data_path)
print("validation path :", validation_data_path)
print("model path :", model_path)
# Out:
# Source path : c:\Users\User\WORK\workspace-ia\PROJETS\projet_cat_or_dog\dataset
# Training path : c:\Users\User\WORK\workspace-ia\PROJETS\projet_cat_or_dog\dataset\training_set
# validation path : c:\Users\User\WORK\workspace-ia\PROJETS\projet_cat_or_dog\dataset\validation_set

# %%
model_save_names =  [f"cnn{i}.pkl" for i in range(1, 5)]
model_force_train = {}
for model_name in model_force_train:
    file_path = join(model_path, model_name)
    model_force_train[model_name] = not exists(file_path)
model_force_train

# %% [markdown]
# <div style="display: flex; background-color: blue;" >
#
# # 2.Modèle simple
# </div>

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### 2.1. Chargement des données
# </div>

# %% [markdown]
# <div style="display: flex; background-color: indigo;" >
#
# #### 2.1.1. Nettoyage des données
# </div>
#
# ```
# Deleted 1578 images.
# Deleted 0 images.
# ```
# Images supprimées du dataset au premier tour (aux prochaines exécutions, les chiffres devraient être à 0, donc pour mémoire)

# %%
# Il faut supprimer les images qui ne sont pas compatibles
removed_files = del_corrupt_img(training_data_path, include_sub_dir=1, verbose=verbose)
removed_files.extend(del_corrupt_img(validation_data_path, include_sub_dir=1, verbose=verbose))
# Out:
# Deleted 1578 images.
# Deleted 0 images.

# %% [markdown]
# <div style="display: flex; background-color: indigo;" >
#
# #### 2.1.2. Chargement et standardisation des données
# </div>

# %% [markdown]
# Dans le dataset les dimensions les plus petites sont :
# - dog : 58 x 50
# - cat : 4x4, puis 50x50
#
# On ne prend pas en compte l'image en 4x4, la taille la plus petite est donc 50x50.

# %%
# target_size=(64,64) # la taille de la plus petite image
target_size=(50,50) # la taille de la plus petite image
batch_size = 32
class_mode='binary'
rescale=1./255 # standardisation des données des images

# %%
train_datgen=ImageDataGenerator(rescale=rescale, shear_range=0.2,zoom_range=0.2, horizontal_flip=True)
training_set=train_datgen.flow_from_directory(training_data_path,     target_size=target_size,batch_size=batch_size,class_mode=class_mode)
validation_set=train_datgen.flow_from_directory(validation_data_path, target_size=target_size,batch_size=batch_size,class_mode=class_mode)
# Out:
# Found 25570 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# <div style="display: flex; background-color: indigo;" >
#
# #### 2.1.3. Identification des labels
# </div>

# %%
print(training_set.class_indices)
labels = list(training_set.class_indices.keys())
labels
# Out:
# {'cat': 0, 'dog': 1}
# ['cat', 'dog']

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### 2.2. Création du réseau de neurones
# </div>

# %%
model_name = ""

# %%
def create_and_fit_cnn1(verbose = 0):
    cnn=tf.keras.models.Sequential()

    cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,activation='relu',input_shape=[target_size[0],target_size[1],3]))
    cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

    cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,activation='relu'))
    cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

    cnn.add(tf.keras.layers.Flatten())

    cnn.add(tf.keras.layers.Dense(units=128,activation='relu'))

    cnn.add(tf.keras.layers.Dense(units=1,activation='sigmoid'))
    if verbose:
        print(cnn.summary())
    
    #  Compilation et entrainement
    opt = Adam(learning_rate=0.000001)
    cnn.compile(optimizer = opt , loss = 'binary_crossentropy' , metrics = ['accuracy'])
    
    # Entrainement

    return cnn

# %%
cnn = None

if model_force_train.get(model_name, True):
    cnn = create_and_fit_cnn1(verbose=verbose)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 24, 24, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 22, 22, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 11, 11, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 3872)              0
#
#  dense (Dense)               (None, 128)               495744
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 506,017
# Trainable params: 506,017
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(cnn, show_shapes=True)

# %% [markdown]
# <div style="display: flex; background-color: indigo;" >
#
# #### 2.2.2. Compilation et entrainement
# </div>

# %% [markdown]
# Résultats avec :
#
# | Epoch | Train cat          | Train dog         | Res |
# |-------|--------------------|-------------------|-----|
# | 50/50 | 1 029              | 1 119             |`68/68 [==============================] - 11s 168ms/step - loss: 0.6710 - accuracy: 0.5945 - val_loss: 0.6762 - val_accuracy: 0.5780`|
# | 50/50 | 1 029 + 12 500     | 1 119 + 12 500    |`800/800 [==============================] - 70s 88ms/step - loss: 0.6185 - accuracy: 0.6745 - val_loss: 0.6189 - val_accuracy: 0.6740`|
#
# Ajout de 12 500 images par catégorie (source : PetImages), après suppression des images corrompues :
#
# ```
# Training : Found 25570 images belonging to 2 classes.
# Validation : Found 2000 images belonging to 2 classes.
# ```

# %%
if 
epochs = 50
history_cnn = cnn.fit(training_set, epochs = epochs , validation_data=validation_set)
cnn.save('models/cnn1.pkl')
# Out:
# Epoch 1/50
# 800/800 [==============================] - 73s 91ms/step - loss: 0.6923 - accuracy: 0.5171 - val_loss: 0.6918 - val_accuracy: 0.5130
# Epoch 2/50
# 800/800 [==============================] - 65s 81ms/step - loss: 0.6903 - accuracy: 0.5327 - val_loss: 0.6897 - val_accuracy: 0.5300
# Epoch 3/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.6885 - accuracy: 0.5628 - val_loss: 0.6879 - val_accuracy: 0.5630
# Epoch 4/50
# 800/800 [==============================] - 62s 77ms/step - loss: 0.6867 - accuracy: 0.5764 - val_loss: 0.6865 - val_accuracy: 0.5850
# Epoch 5/50
# 800/800 [==============================] - 71s 89ms/step - loss: 0.6847 - accuracy: 0.5891 - val_loss: 0.6838 - val_accuracy: 0.5960
# Epoch 6/50
# 800/800 [==============================] - 70s 87ms/step - loss: 0.6830 - accuracy: 0.6021 - val_loss: 0.6825 - val_accuracy: 0.6060
# Epoch 7/50
# 800/800 [==============================] - 72s 89ms/step - loss: 0.6815 - accuracy: 0.6138 - val_loss: 0.6806 - val_accuracy: 0.5945
# Epoch 8/50
# 800/800 [==============================] - 69s 86ms/step - loss: 0.6795 - accuracy: 0.6151 - val_loss: 0.6789 - val_accuracy: 0.6295
# Epoch 9/50
# 800/800 [==============================] - 73s 91ms/step - loss: 0.6778 - accuracy: 0.6244 - val_loss: 0.6769 - val_accuracy: 0.6145
# Epoch 10/50
# 800/800 [==============================] - 74s 93ms/step - loss: 0.6760 - accuracy: 0.6254 - val_loss: 0.6746 - val_accuracy: 0.6365
# Epoch 11/50
# 800/800 [==============================] - 76s 95ms/step - loss: 0.6744 - accuracy: 0.6267 - val_loss: 0.6742 - val_accuracy: 0.6255
# Epoch 12/50
# 800/800 [==============================] - 67s 83ms/step - loss: 0.6720 - accuracy: 0.6309 - val_loss: 0.6709 - val_accuracy: 0.6485
# Epoch 13/50
# 800/800 [==============================] - 72s 90ms/step - loss: 0.6704 - accuracy: 0.6341 - val_loss: 0.6703 - val_accuracy: 0.6300
# Epoch 14/50
# 800/800 [==============================] - 80s 100ms/step - loss: 0.6684 - accuracy: 0.6371 - val_loss: 0.6676 - val_accuracy: 0.6365
# Epoch 15/50
# 800/800 [==============================] - 76s 95ms/step - loss: 0.6665 - accuracy: 0.6397 - val_loss: 0.6647 - val_accuracy: 0.6420
# Epoch 16/50
# 800/800 [==============================] - 76s 95ms/step - loss: 0.6645 - accuracy: 0.6397 - val_loss: 0.6637 - val_accuracy: 0.6550
# Epoch 17/50
# 800/800 [==============================] - 65s 81ms/step - loss: 0.6627 - accuracy: 0.6424 - val_loss: 0.6627 - val_accuracy: 0.6405
# Epoch 18/50
# 800/800 [==============================] - 68s 85ms/step - loss: 0.6614 - accuracy: 0.6433 - val_loss: 0.6597 - val_accuracy: 0.6555
# Epoch 19/50
# 800/800 [==============================] - 65s 82ms/step - loss: 0.6596 - accuracy: 0.6451 - val_loss: 0.6573 - val_accuracy: 0.6480
# Epoch 20/50
# 800/800 [==============================] - 74s 92ms/step - loss: 0.6578 - accuracy: 0.6472 - val_loss: 0.6565 - val_accuracy: 0.6470
# Epoch 21/50
# 800/800 [==============================] - 74s 93ms/step - loss: 0.6562 - accuracy: 0.6487 - val_loss: 0.6549 - val_accuracy: 0.6580
# Epoch 22/50
# 800/800 [==============================] - 73s 92ms/step - loss: 0.6545 - accuracy: 0.6492 - val_loss: 0.6541 - val_accuracy: 0.6485
# Epoch 23/50
# 800/800 [==============================] - 73s 91ms/step - loss: 0.6533 - accuracy: 0.6504 - val_loss: 0.6520 - val_accuracy: 0.6560
# Epoch 24/50
# 800/800 [==============================] - 79s 99ms/step - loss: 0.6512 - accuracy: 0.6490 - val_loss: 0.6515 - val_accuracy: 0.6490
# Epoch 25/50
# 800/800 [==============================] - 75s 93ms/step - loss: 0.6496 - accuracy: 0.6503 - val_loss: 0.6499 - val_accuracy: 0.6460
# Epoch 26/50
# 800/800 [==============================] - 77s 96ms/step - loss: 0.6486 - accuracy: 0.6506 - val_loss: 0.6470 - val_accuracy: 0.6535
# Epoch 27/50
# 800/800 [==============================] - 76s 95ms/step - loss: 0.6470 - accuracy: 0.6531 - val_loss: 0.6455 - val_accuracy: 0.6545
# Epoch 28/50
# 800/800 [==============================] - 75s 94ms/step - loss: 0.6455 - accuracy: 0.6542 - val_loss: 0.6434 - val_accuracy: 0.6615
# Epoch 29/50
# 800/800 [==============================] - 74s 92ms/step - loss: 0.6439 - accuracy: 0.6539 - val_loss: 0.6430 - val_accuracy: 0.6460
# Epoch 30/50
# 800/800 [==============================] - 76s 95ms/step - loss: 0.6427 - accuracy: 0.6569 - val_loss: 0.6432 - val_accuracy: 0.6620
# Epoch 31/50
# 800/800 [==============================] - 74s 93ms/step - loss: 0.6410 - accuracy: 0.6564 - val_loss: 0.6410 - val_accuracy: 0.6625
# Epoch 32/50
# 800/800 [==============================] - 77s 97ms/step - loss: 0.6399 - accuracy: 0.6563 - val_loss: 0.6404 - val_accuracy: 0.6495
# Epoch 33/50
# 800/800 [==============================] - 77s 96ms/step - loss: 0.6382 - accuracy: 0.6567 - val_loss: 0.6364 - val_accuracy: 0.6780
# Epoch 34/50
# 800/800 [==============================] - 77s 97ms/step - loss: 0.6371 - accuracy: 0.6591 - val_loss: 0.6361 - val_accuracy: 0.6670
# Epoch 35/50
# 800/800 [==============================] - 75s 94ms/step - loss: 0.6356 - accuracy: 0.6635 - val_loss: 0.6351 - val_accuracy: 0.6670
# Epoch 36/50
# 800/800 [==============================] - 73s 91ms/step - loss: 0.6349 - accuracy: 0.6628 - val_loss: 0.6362 - val_accuracy: 0.6640
# Epoch 37/50
# 800/800 [==============================] - 75s 93ms/step - loss: 0.6334 - accuracy: 0.6646 - val_loss: 0.6331 - val_accuracy: 0.6640
# Epoch 38/50
# 800/800 [==============================] - 64s 80ms/step - loss: 0.6316 - accuracy: 0.6620 - val_loss: 0.6316 - val_accuracy: 0.6690
# Epoch 39/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.6308 - accuracy: 0.6653 - val_loss: 0.6297 - val_accuracy: 0.6725
# Epoch 40/50
# 800/800 [==============================] - 58s 73ms/step - loss: 0.6301 - accuracy: 0.6653 - val_loss: 0.6284 - val_accuracy: 0.6685
# Epoch 41/50
# 800/800 [==============================] - 60s 74ms/step - loss: 0.6289 - accuracy: 0.6679 - val_loss: 0.6290 - val_accuracy: 0.6610
# Epoch 42/50
# 800/800 [==============================] - 61s 76ms/step - loss: 0.6277 - accuracy: 0.6667 - val_loss: 0.6308 - val_accuracy: 0.6625
# Epoch 43/50
# 800/800 [==============================] - 67s 84ms/step - loss: 0.6257 - accuracy: 0.6686 - val_loss: 0.6257 - val_accuracy: 0.6595
# Epoch 44/50
# 800/800 [==============================] - 60s 75ms/step - loss: 0.6257 - accuracy: 0.6684 - val_loss: 0.6242 - val_accuracy: 0.6710
# Epoch 45/50
# 800/800 [==============================] - 59s 74ms/step - loss: 0.6240 - accuracy: 0.6689 - val_loss: 0.6248 - val_accuracy: 0.6680
# Epoch 46/50
# 800/800 [==============================] - 61s 76ms/step - loss: 0.6236 - accuracy: 0.6671 - val_loss: 0.6244 - val_accuracy: 0.6770
# Epoch 47/50
# 800/800 [==============================] - 60s 76ms/step - loss: 0.6226 - accuracy: 0.6697 - val_loss: 0.6224 - val_accuracy: 0.6675
# Epoch 48/50
# 800/800 [==============================] - 59s 74ms/step - loss: 0.6211 - accuracy: 0.6722 - val_loss: 0.6225 - val_accuracy: 0.6650
# Epoch 49/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.6198 - accuracy: 0.6720 - val_loss: 0.6195 - val_accuracy: 0.6640
# Epoch 50/50
# 800/800 [==============================] - 70s 88ms/step - loss: 0.6185 - accuracy: 0.6745 - val_loss: 0.6189 - val_accuracy: 0.6740

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### 2.3. Evaluation de l'entrainement
# </div>

# %%
show_learning_graph(history=history_cnn, epochs=epochs, verbose=verbose)

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### 2.4. Prédiction
# </div>

# %% [markdown]
# <div style="display: flex; background-color: indigo;" >
#
# #### 2.4.1. 1 image
# </div>

# %%
img_test = r'C:\Users\User\WORK\workspace-ia\PROJETS\projet_cat_or_dog\dataset\aurelie_validation_set\dog\dog.001 (1).jpeg'

plt.figure(figsize=(5, 5))
imread = cv2.imread(img_test)
plt.imshow(imread)
plt.show()

# %%
found, predict_class = predict_img(model=cnn,img_test=img_test, target_size=target_size, labels=labels,label_expected="dog",verbose=verbose)
found, predict_class
# Out:
# 1/1 [==============================] - 3s 3s/step
# (1, 1)

# %% [markdown]
# <div style="display: flex; background-color: indigo;" >
#
# #### 2.4.2. Quelques images
# </div>

# %%
aurelie_test, aurelie_y = get_aurelie_test()
df_cm, fail_files = predict_n_img(cnn, aurelie_test, aurelie_y,target_size, labels, verbose=verbose)
# Out:
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 22ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 20ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 18ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 17ms/step
# cat expected (predict_class : 1), dog predict

# %% [markdown]
# <div style="display: flex; background-color: indigo;" >
#
# #### 2.4.3. N images
# </div>

# %%
aurelie_test, aurelie_y = get_aurelie_full_test(label_codes=training_set.class_indices)
df_cm, fail_files = predict_n_img(cnn, aurelie_test, aurelie_y,target_size, labels, verbose=verbose)
# Out:
# 1/1 [==============================] - 0s 23ms/step
# cat expected (predict_class : 1), dog predict
# 1 C:\Users\User\WORK\workspace-ia\PROJETS\projet_cat_or_dog\dataset\aurelie_validation_set\cat\cat.001 (1).jpg cannot identify image file <_io.BytesIO object at 0x0000015E80524630>
# 1/1 [==============================] - 0s 18ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 24ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 19ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 22ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 29ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 28ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 21ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 32ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 25ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 33ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 15ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 18ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 18ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 18ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 18ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 18ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 18ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 21ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 16ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 15ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 18ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 18ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 18ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 20ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 20ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 19ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 16ms/step
# cat expected (predict_class : 1), dog predict
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 64 C:\Users\User\WORK\workspace-ia\PROJETS\projet_cat_or_dog\dataset\aurelie_validation_set\dog\dog.001 (140).jpg broken data stream when reading image file
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 91 C:\Users\User\WORK\workspace-ia\PROJETS\projet_cat_or_dog\dataset\aurelie_validation_set\dog\dog.001 (165).jpg broken data stream when reading image file
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 94 C:\Users\User\WORK\workspace-ia\PROJETS\projet_cat_or_dog\dataset\aurelie_validation_set\dog\dog.001 (168).jpg broken data stream when reading image file
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 173 C:\Users\User\WORK\workspace-ia\PROJETS\projet_cat_or_dog\dataset\aurelie_validation_set\dog\dog.001 (240).jpg broken data stream when reading image file
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 221 C:\Users\User\WORK\workspace-ia\PROJETS\projet_cat_or_dog\dataset\aurelie_validation_set\dog\dog.001 (288).jpg broken data stream when reading image file
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# dog expected (predict_class : 0), cat predict
# 1/1 [==============================] - 0s 19ms/step
# dog expected (predict_class : 0), cat predict
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 16ms/step
# dog expected (predict_class : 0), cat predict
# 255 C:\Users\User\WORK\workspace-ia\PROJETS\projet_cat_or_dog\dataset\aurelie_validation_set\dog\dog.001 (332).jpg broken data stream when reading image file
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 327 C:\Users\User\WORK\workspace-ia\PROJETS\projet_cat_or_dog\dataset\aurelie_validation_set\dog\dog.001 (405).jpg broken data stream when reading image file
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 379 C:\Users\User\WORK\workspace-ia\PROJETS\projet_cat_or_dog\dataset\aurelie_validation_set\dog\dog.001 (457).jpg broken data stream when reading image file
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 408 C:\Users\User\WORK\workspace-ia\PROJETS\projet_cat_or_dog\dataset\aurelie_validation_set\dog\dog.001 (494).jpg broken data stream when reading image file
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 439 C:\Users\User\WORK\workspace-ia\PROJETS\projet_cat_or_dog\dataset\aurelie_validation_set\dog\dog.001 (522).jpg broken data stream when reading image file
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# dog expected (predict_class : 0), cat predict
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 470 C:\Users\User\WORK\workspace-ia\PROJETS\projet_cat_or_dog\dataset\aurelie_validation_set\dog\dog.001 (550).jpg broken data stream when reading image file
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 566 C:\Users\User\WORK\workspace-ia\PROJETS\projet_cat_or_dog\dataset\aurelie_validation_set\dog\dog.001 (653).jpg broken data stream when reading image file
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 579 C:\Users\User\WORK\workspace-ia\PROJETS\projet_cat_or_dog\dataset\aurelie_validation_set\dog\dog.001 (667).jpg broken data stream when reading image file
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# dog expected (predict_class : 0), cat predict
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# dog expected (predict_class : 0), cat predict
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# dog expected (predict_class : 0), cat predict
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# dog expected (predict_class : 0), cat predict
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### 2.5. Conclusion
# </div>
#
# Malgré l'ajout de données, ce modèle ne prédit que des chiens... Il faut donc revoir le modèle.

# %% [markdown]
# <div style="display: flex; background-color: blue;" >
#
# # 3.Modèle pré-entrainés
# </div>
#
# https://keras.io/api/applications/#usage-examples-for-image-classification-models
#
# Résultats des tests : (cf. notebook excluded model)
#
# |Model   | Commentaires                                                                                                       |
# |--------|--------------------------------------------------------------------------------------------------------------------|
# |ResNet50| Toutes les images testées ont été classifiées en : `Predicted: [('n02102318', 'cocker_spaniel', 0.07705149), ('n02106550', 'Rottweiler', 0.07325226), ('n02102480', 'Sussex_spaniel', 0.07100144)]`, même les images de chat|
# | VGG16  | Permet d'extraire des features|
# | VGG19  | Permet d'extraire des features|
# | InceptionV3 | Résultat avec 50 Epoch : `800/800 [==============================] - 60s 75ms/step - loss: nan - accuracy: 0.4997 - val_loss: nan - val_accuracy: 0.5000`|

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### 3.2. ResNet50
# </div>
#
# <div style="display: flex; background-color: indigo;" >
#
# #### 3.2.1. Utilisation directe
# </div>
#
# Toutes les images testées ont été classifiées en : `Predicted: [('n02102318', 'cocker_spaniel', 0.07705149), ('n02106550', 'Rottweiler', 0.07325226), ('n02102480', 'Sussex_spaniel', 0.07100144)]`, même les images de chat.
# Ce modèle n'est donc pas adapté tel quel.
#
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### 3.3. VGG*
# </div>
#
# VGG16 et VGG19 permettent d'extraire des features, qui doivent certainement être utilisées par ailleurs. ?
#
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### 3.4. InceptionV3
# </div>
#
# 1. Récupération du modèle
# 1. Customisation du modèle
# 1. Compilation et apprentissage sur les données du projet
# 1. Résultat avec 50 Epoch : `800/800 [==============================] - 60s 75ms/step - loss: nan - accuracy: 0.4997 - val_loss: nan - val_accuracy: 0.5000`
#
# Ce modèle ne semble pas adapté à notre besoin, de plus il est beaucoup trop complexe.

# %% [markdown]
# <div style="display: flex; background-color: blue;" >
#
# # 4.Nouvelle version du Modèle
# </div>

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### 4.1.Création du modèle
# </div>

# %%
model_cnn_2 = make_model(input_shape=target_size + (3,), num_classes=2, data_augmentation=False)
keras.utils.plot_model(model_cnn_2, show_shapes=True)

# %% [markdown]
# <div style="display: flex; background-color: indigo;" >
#
# #### 4.1.2. Compilation et entrainement
# </div>

# %%
opt = Adam(learning_rate=0.000001)
model_cnn_2.compile(optimizer = opt , loss = 'binary_crossentropy' , metrics = ['accuracy'])

# %% [markdown]
# <div style="display: flex; background-color: indigo;" >
#
# #### 4.1.3. Entrainement
# </div>

# %%
# @see : https://keras.io/api/callbacks/model_checkpoint/
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="model_check_point/cnn_v2_best.h5",
        save_best_only=False,
        verbose=verbose,
        )
]

# %% [markdown]
# `Epoch 25/50`
#
# `800/800 [==============================] - 264s 330ms/step - loss: 0.5798 - accuracy: 0.6946 - val_loss: 0.5567 - val_accuracy: 0.7170`

# %%
epochs = 50
history_cnn2 = model_cnn_2.fit(training_set, epochs = epochs , validation_data=validation_set, callbacks=callbacks)
# Out:
# Epoch 1/50
# 800/800 [==============================] - 257s 319ms/step - loss: 0.7229 - accuracy: 0.5246 - val_loss: 0.6835 - val_accuracy: 0.5400
# Epoch 2/50
# 800/800 [==============================] - 247s 309ms/step - loss: 0.6855 - accuracy: 0.5737 - val_loss: 0.6461 - val_accuracy: 0.6385
# Epoch 3/50
# 800/800 [==============================] - 255s 319ms/step - loss: 0.6721 - accuracy: 0.5938 - val_loss: 0.6375 - val_accuracy: 0.6440
# Epoch 4/50
# 800/800 [==============================] - 241s 302ms/step - loss: 0.6579 - accuracy: 0.6157 - val_loss: 0.6223 - val_accuracy: 0.6600
# Epoch 5/50
# 800/800 [==============================] - 236s 295ms/step - loss: 0.6523 - accuracy: 0.6205 - val_loss: 0.6206 - val_accuracy: 0.6645
# Epoch 6/50
# 800/800 [==============================] - 231s 288ms/step - loss: 0.6473 - accuracy: 0.6288 - val_loss: 0.6084 - val_accuracy: 0.6785
# Epoch 7/50
# 800/800 [==============================] - 244s 306ms/step - loss: 0.6386 - accuracy: 0.6355 - val_loss: 0.6072 - val_accuracy: 0.6800
# Epoch 8/50
# 800/800 [==============================] - 244s 304ms/step - loss: 0.6351 - accuracy: 0.6422 - val_loss: 0.5975 - val_accuracy: 0.6935
# Epoch 9/50
# 800/800 [==============================] - 225s 281ms/step - loss: 0.6289 - accuracy: 0.6491 - val_loss: 0.5934 - val_accuracy: 0.6860
# Epoch 10/50
# 800/800 [==============================] - 223s 279ms/step - loss: 0.6279 - accuracy: 0.6500 - val_loss: 0.5931 - val_accuracy: 0.6905
# Epoch 11/50
# 800/800 [==============================] - 240s 300ms/step - loss: 0.6197 - accuracy: 0.6585 - val_loss: 0.5896 - val_accuracy: 0.6970
# Epoch 12/50
# 800/800 [==============================] - 265s 332ms/step - loss: 0.6165 - accuracy: 0.6592 - val_loss: 0.5806 - val_accuracy: 0.6980
# Epoch 13/50
# 800/800 [==============================] - 266s 332ms/step - loss: 0.6102 - accuracy: 0.6651 - val_loss: 0.5798 - val_accuracy: 0.6970
# Epoch 14/50
# 800/800 [==============================] - 273s 342ms/step - loss: 0.6068 - accuracy: 0.6688 - val_loss: 0.5770 - val_accuracy: 0.6965
# Epoch 15/50
# 800/800 [==============================] - 272s 340ms/step - loss: 0.6071 - accuracy: 0.6686 - val_loss: 0.5765 - val_accuracy: 0.7120
# Epoch 16/50
# 800/800 [==============================] - 251s 314ms/step - loss: 0.6034 - accuracy: 0.6712 - val_loss: 0.5695 - val_accuracy: 0.7045
# Epoch 17/50
# 800/800 [==============================] - 252s 316ms/step - loss: 0.6014 - accuracy: 0.6716 - val_loss: 0.5713 - val_accuracy: 0.7040
# Epoch 18/50
# 800/800 [==============================] - 263s 328ms/step - loss: 0.5987 - accuracy: 0.6797 - val_loss: 0.5709 - val_accuracy: 0.7025
# Epoch 19/50
# 800/800 [==============================] - 257s 322ms/step - loss: 0.5959 - accuracy: 0.6813 - val_loss: 0.5636 - val_accuracy: 0.7065
# Epoch 20/50
# 800/800 [==============================] - 237s 296ms/step - loss: 0.5927 - accuracy: 0.6846 - val_loss: 0.5682 - val_accuracy: 0.7055
# Epoch 21/50
# 800/800 [==============================] - 230s 288ms/step - loss: 0.5889 - accuracy: 0.6858 - val_loss: 0.5591 - val_accuracy: 0.7035
# Epoch 22/50
# 800/800 [==============================] - 264s 330ms/step - loss: 0.5884 - accuracy: 0.6866 - val_loss: 0.5595 - val_accuracy: 0.7165
# Epoch 23/50
# 800/800 [==============================] - 261s 326ms/step - loss: 0.5838 - accuracy: 0.6894 - val_loss: 0.5636 - val_accuracy: 0.7050
# Epoch 24/50
# 800/800 [==============================] - 263s 329ms/step - loss: 0.5862 - accuracy: 0.6891 - val_loss: 0.5503 - val_accuracy: 0.7130
# Epoch 25/50
# 800/800 [==============================] - 264s 330ms/step - loss: 0.5798 - accuracy: 0.6946 - val_loss: 0.5567 - val_accuracy: 0.7170
# Epoch 26/50
# 372/800 [============>.................] - ETA: 2:22 - loss: 0.5834 - accuracy: 0.6915
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# c:\Users\User\WORK\workspace-ia\PROJETS\projet_cat_or_dog\cat_or_dog_aurelie_v3.simple_resnet.ipynb Cell 46' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/User/WORK/workspace-ia/PROJETS/projet_cat_or_dog/cat_or_dog_aurelie_v3.simple_resnet.ipynb#ch0000045?line=0'>1</a> epochs = 50
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/WORK/workspace-ia/PROJETS/projet_cat_or_dog/cat_or_dog_aurelie_v3.simple_resnet.ipynb#ch0000045?line=1'>2</a> history_cnn2 = model_cnn_2.fit(training_set, epochs = epochs , validation_data=validation_set, callbacks=callbacks)
#
# File c:\Program Files\Python_venv\tensor_flow\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///c%3A/Program%20Files/Python_venv/tensor_flow/lib/site-packages/keras/utils/traceback_utils.py?line=64'>65</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///c%3A/Program%20Files/Python_venv/tensor_flow/lib/site-packages/keras/utils/traceback_utils.py?line=65'>66</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> <a href='file:///c%3A/Program%20Files/Python_venv/tensor_flow/lib/site-packages/keras/utils/traceback_utils.py?line=66'>67</a>   raise e.with_traceback(filtered_tb) from None
#      <a href='file:///c%3A/Program%20Files/Python_venv/tensor_flow/lib/site-packages/keras/utils/traceback_utils.py?line=67'>68</a> finally:
#      <a href='file:///c%3A/Program%20Files/Python_venv/tensor_flow/lib/site-packages/keras/utils/traceback_utils.py?line=68'>69</a>   del filtered_tb
#
# File c:\Program Files\Python_venv\tensor_flow\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      <a href='file:///c%3A/Program%20Files/Python_venv/tensor_flow/lib/site-packages/tensorflow/python/eager/execute.py?line=51'>52</a> try:
#      <a href='file:///c%3A/Program%20Files/Python_venv/tensor_flow/lib/site-packages/tensorflow/python/eager/execute.py?line=52'>53</a>   ctx.ensure_initialized()
# ---> <a href='file:///c%3A/Program%20Files/Python_venv/tensor_flow/lib/site-packages/tensorflow/python/eager/execute.py?line=53'>54</a>   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      <a href='file:///c%3A/Program%20Files/Python_venv/tensor_flow/lib/site-packages/tensorflow/python/eager/execute.py?line=54'>55</a>                                       inputs, attrs, num_outputs)
#      <a href='file:///c%3A/Program%20Files/Python_venv/tensor_flow/lib/site-packages/tensorflow/python/eager/execute.py?line=55'>56</a> except core._NotOkStatusException as e:
#      <a href='file:///c%3A/Program%20Files/Python_venv/tensor_flow/lib/site-packages/tensorflow/python/eager/execute.py?line=56'>57</a>   if name is not None:
#
# UnknownError: Graph execution error:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:\\Users\\User\\WORK\\workspace-ia\\PROJETS\\projet_cat_or_dog\\dataset\\training_set\\dog\\dog.1 (3075).jpg'
# Traceback (most recent call last):
#
#   File "c:\Program Files\Python_venv\tensor_flow\lib\site-packages\tensorflow\python\ops\script_ops.py", line 270, in __call__
#     ret = func(*args)
#
#   File "c:\Program Files\Python_venv\tensor_flow\lib\site-packages\tensorflow\python\autograph\impl\api.py", line 642, in wrapper
#     return func(*args, **kwargs)
#
#   File "c:\Program Files\Python_venv\tensor_flow\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py", line 1030, in generator_py_func
#     values = next(generator_state.get_iterator(iterator_id))
#
#   File "c:\Program Files\Python_venv\tensor_flow\lib\site-packages\keras\engine\data_adapter.py", line 831, in wrapped_generator
#     for data in generator_fn():
#
#   File "c:\Program Files\Python_venv\tensor_flow\lib\site-packages\keras\engine\data_adapter.py", line 957, in generator_fn
#     yield x[i]
#
#   File "c:\Program Files\Python_venv\tensor_flow\lib\site-packages\keras\preprocessing\image.py", line 110, in __getitem__
#     return self._get_batches_of_transformed_samples(index_array)
#
#   File "c:\Program Files\Python_venv\tensor_flow\lib\site-packages\keras\preprocessing\image.py", line 337, in _get_batches_of_transformed_samples
#     img = image_utils.load_img(
#
#   File "c:\Program Files\Python_venv\tensor_flow\lib\site-packages\keras\utils\image_utils.py", line 393, in load_img
#     with open(path, 'rb') as f:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:\\Users\\User\\WORK\\workspace-ia\\PROJETS\\projet_cat_or_dog\\dataset\\training_set\\dog\\dog.1 (3075).jpg'
#
#
# 	 [[{{node PyFunc}}]]
# 	 [[IteratorGetNext]] [Op:__inference_train_function_4104]

# %% [markdown]
# <div style="display: flex; background-color: indigo;" >
#
# #### 4.1.4. Evaluation du modèle
# </div>

# %%
show_learning_graph(history=history_cnn2, epochs=epochs, verbose=verbose)

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### 4.2. Prédiction
# </div>

# %% [markdown]
# <div style="display: flex; background-color: indigo;" >
#
# #### 4.2.1. 1 image
# </div>

# %%
img_test = r'C:\Users\User\WORK\workspace-ia\PROJETS\projet_cat_or_dog\dataset\aurelie_validation_set\dog\dog.001 (1).jpeg'

plt.figure(figsize=(5, 5))
imread = cv2.imread(img_test)
plt.imshow(imread)
plt.show()

# %%
found, predict_class = predict_img(model=model_cnn_2,img_test=img_test, target_size=target_size, labels=labels,label_expected="dog",verbose=verbose)

if found :
    print(f"Expected : dog, found : {labels[predict_class]}"
else:
    print(f"Expected : dog, not found : {labels[predict_class]}"
# Out:
# 1/1 [==============================] - 3s 3s/step
# (1, 1)

# %% [markdown]
# <div style="display: flex; background-color: indigo;" >
#
# #### 4.2.2. Quelques images
# </div>

# %%
aurelie_test, aurelie_y = get_aurelie_test()
df_cm, fail_files = predict_n_img(model_cnn_2, aurelie_test, aurelie_y,target_size, labels, verbose=verbose)

# %% [markdown]
# <div style="display: flex; background-color: indigo;" >
#
# #### 4.2.3. N images
# </div>

# %%
aurelie_test, aurelie_y = get_aurelie_full_test(label_codes=training_set.class_indices)
df_cm, fail_files = predict_n_img(model_cnn_2, aurelie_test, aurelie_y,target_size, labels, verbose=verbose)

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### 4.3. Conclusion
# </div>
#
# ...

# %% [markdown]
# <div style="display: flex; background-color: blue;" >
#
# # 5. Essai d'optimisation
# </div>
#
# Traitements possibles pour améliorer les prédictions :
# - Augmenter les données de train :
#   - Niveau 1 => ajouter des données => FAIT
#   - Niveau 2 => augmenter les données existantes (faire pivoter les images)
#   - Essayer en noir et blanc ?
#
# - Traiter les images :
#   - Augmenter la taille des images (rezise)
#   - Enlever les flous
#   - Equalizer les images
#
# - Utiliser les CIF :
#   - Identifier les descripteurs
#   - traiter les descripteurs et non les pixels,
#
# - Modèles :
#   - Améliorer les paramètres
#   - Augmenter les couches

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### 5.1. essai 1 : taille des images
# </div>

# %%
target_size_optimised=(180,180) # la taille de la plus petite image
batch_size_optimised = 32
class_mode='binary'
rescale=1./255 # standardisation des données des images

# %%
train_datgen=ImageDataGenerator(rescale=rescale, shear_range=0.2,zoom_range=0.2, horizontal_flip=True)
training_set_up=train_datgen.flow_from_directory(training_data_path,     target_size=target_size_optimised,batch_size=batch_size_optimised,class_mode=class_mode)
validation_set_up=train_datgen.flow_from_directory(validation_data_path, target_size=target_size_optimised,batch_size=batch_size_optimised,class_mode=class_mode)

# %%
model_cnn_3 = make_model(input_shape=target_size + (3,), num_classes=2, data_augmentation=False)
keras.utils.plot_model(model_cnn_3, show_shapes=True)

# %%
opt = Adam(learning_rate=0.000001)
model_cnn_3.compile(optimizer = opt , loss = 'binary_crossentropy' , metrics = ['accuracy'])

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint("model_check_point/cnn_v3/save_at_{epoch}.h5"),
]

# %%
epochs = 50
history_cnn3 = model_cnn_3.fit(training_set_up, epochs = epochs , validation_data=validation_set_up, callbacks=callbacks)

# %%
show_learning_graph(history=history_cnn3, epochs=epochs, verbose=verbose)

# %%
found, predict_class = predict_img(model=model_cnn_3,img_test=img_test, target_size=target_size, labels=labels,label_expected="dog",verbose=verbose)

if found :
    print(f"Expected : dog, found : {labels[predict_class]}"
else:
    print(f"Expected : dog, not found : {labels[predict_class]}"

# %%
aurelie_test, aurelie_y = get_aurelie_test()
df_cm, fail_files = predict_n_img(model_cnn_3, aurelie_test, aurelie_y,target_size, labels, verbose=verbose)

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### 5.2. essai 1 - data augmentation
# </div>
#
# A priori lorsqu'on dispose de peu de données il est recommandé d'appliquer ce traitement pour avoir différents points de vue d'une même image et donc avoir plus de données.

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
    ]
)

# %%
model_cnn_4 = make_model(input_shape=target_size + (3,), num_classes=2, data_augmentation=data_augmentation)
keras.utils.plot_model(model_cnn_3, show_shapes=True)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint("model_check_point/cnn_v4/save_at_{epoch}.h5"),
]

# %%
epochs = 50
history_cnn4 = model_cnn_4.fit(training_set_up, epochs = epochs , validation_data=validation_set_up, callbacks=callbacks)

# %%
show_learning_graph(history=history_cnn4, epochs=epochs, verbose=verbose)

# %%
found, predict_class = predict_img(model=model_cnn_4,img_test=img_test, target_size=target_size, labels=labels,label_expected="dog",verbose=verbose)

if found :
    print(f"Expected : dog, found : {labels[predict_class]}"
else:
    print(f"Expected : dog, not found : {labels[predict_class]}"

# %%
aurelie_test, aurelie_y = get_aurelie_test()
df_cm, fail_files = predict_n_img(model_cnn_4, aurelie_test, aurelie_y,target_size, labels, verbose=verbose)

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### 5.3. Traiter les images avec les histogrammes
# </div>
#
# Enlever les fllous, uniformiser, ...

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### 5.4. CIF
# </div>
#
# Identifier les descripteurs, les points clés pour simplifier, les traitements et au besoin ajouter des couches.
